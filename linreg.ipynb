# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
col = ['x','y']
df = pd.read_csv('/content/Food-Truck(For Linear Regression Program) (1).csv' , names = col)
df.head()
# Out:
#         x        y
# 0  6.1101  17.5920
# 1  5.5277   9.1302
# 2  8.5186  13.6620
# 3  7.0032  11.8540
# 4  5.8598   6.8233

# %%
plt.scatter(df['x'], df['y'])
plt.show()

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.837873
# y  0.837873  1.000000

# %%
# Calculate means
m_x, m_y = np.mean(df['x']), np.mean(df['y'])
print('Mean of x:', m_x)
print('Mean of y:', m_y)
# Out:
# Mean of x: 8.159799999999999
# Mean of y: 5.839135051546393

# %%
# Calculate standard deviations
sd_x, sd_y = np.std(df['x']), np.std(df['y'])
print('Standard deviation of x:', sd_x)
print('Standard deviation of y:', sd_y)
# Out:
# Standard deviation of x: 3.8498839959227156
# Standard deviation of y: 5.48178525707763

# %%
# Calculate Pearson correlation coefficient (r)
r = np.corrcoef(df['x'], df['y'])[0, 1]
print("Pearson Correlation Coefficient (r):", r)
# Out:
# Pearson Correlation Coefficient (r): 0.837873232526341

# %%
# Calculate the slope (b) and intercept (a) for linear regression
b = r * (sd_y / sd_x)
a = m_y - (b * m_x)
print("Slope (b) Coefficient:", b)
print("Intercept (a) Coefficient:", a)
# Out:
# Slope (b) Coefficient: 1.193033644189594
# Intercept (a) Coefficient: -3.8957808783118537

# %%
# Calculate predicted y values and residuals
df['y`'] = df['x'] * b + a
df['y - y`'] = df['y'] - df['y`']

# %%
df.head()
# Out:
#         x        y        y`     y - y`
# 0  6.1101  17.5920  3.393774  14.198226
# 1  5.5277   9.1302  2.698951   6.431249
# 2  8.5186  13.6620  6.267196   7.394804
# 3  7.0032  11.8540  4.459272   7.394728
# 4  5.8598   6.8233  3.095158   3.728142

# %%
# Calculate sum of squared residuals (SSR), sum of squared errors (SSE), and total sum of squares (SST)

y_mean = np.mean(df['y'])

# Calculate Sum of Squares Total (SST)
sst = np.sum((df['y'] - y_mean) ** 2)

# Calculate Sum of Squares Regression (SSR)
ssr = np.sum((df['y`'] - y_mean) ** 2)

# Calculate Sum of Squares Error (SSE)
sse = np.sum((df['y`'] - df['y']) ** 2)

# %%
plt.scatter(df['x'], df['y'])
plt.plot(df['x'], b * df['x'] + a, color='red', label='Linear Regression Line')

# Display the plot
plt.legend()
plt.show()

# %%
r2 = 1 - (ssr / sst)

# %%
print("SSE (Sum of Squared Errors) :", sse)
print("SSR (Sum of Squared Regression) :", ssr)
print("sum of squares (sst) :", sst)
print("R-squared (Coefficient of Determination) :", r2)
# Out:
# SSE (Sum of Squared Errors) : 868.5324469391845
# SSR (Sum of Squared Regression) : 2046.314604718041
# sum of squares (sst) : 2914.8470516572247
# R-squared (Coefficient of Determination) : 0.29796844621585994
